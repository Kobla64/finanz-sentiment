# %% [raw]
# import pandas as pd
#
# # Daten laden
# df = pd.read_csv("data/raw_stock_data.csv")
#
# # Die ersten 5 Zeilen und Infos anzeigen
# print(df.head())
# print(df.info())

# %%
import pandas as pd

# Daten laden
df = pd.read_csv("data/raw_stock_data.csv")

# Die ersten 5 Zeilen und Infos anzeigen
print(df.head())
print(df.info())
# Out:
#          Date         price
# 0  2024-01-02  16769.359375
# 1  2024-01-03  16538.390625
# 2  2024-01-04  16617.289062
# 3  2024-01-05  16594.210938
# 4  2024-01-08  16716.470703
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    504 non-null    object
#  1   price   504 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.0+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Beim Einlesen direkt sagen, dass die erste Spalte (0) das Datum ist
df = pd.read_csv("data/raw_stock_data.csv", index_col=0, parse_dates=True)

# Jetzt ist das Datum der Index und bereits im richtigen Zeitformat
df['price'].plot(figsize=(10, 5), title="DAX Kursverlauf 2024")
plt.grid()
plt.show()
